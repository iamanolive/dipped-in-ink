# %% [markdown]
# <a href="https://colab.research.google.com/github/iamanolive/seven-days-of-AI/blob/main/laurence-moroney/chapter01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print("TensorFlow Version:", tf.__version__)
# Out:
# TensorFlow Version: 2.15.0

# %%
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
l0 = Dense(units = 1, input_shape = [1])
model = Sequential([l0])
model.compile(optimizer = "sgd", loss = "mean_squared_error")

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype = float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype = float)

# %%
model.fit(xs, ys, epochs = 500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 280ms/step - loss: 28.4842
# Epoch 2/500
# 1/1 [==============================] - 0s 10ms/step - loss: 22.7161
# Epoch 3/500
# 1/1 [==============================] - 0s 9ms/step - loss: 18.1718
# Epoch 4/500
# 1/1 [==============================] - 0s 10ms/step - loss: 14.5905
# Epoch 5/500
# 1/1 [==============================] - 0s 8ms/step - loss: 11.7668
# Epoch 6/500
# 1/1 [==============================] - 0s 8ms/step - loss: 9.5393
# Epoch 7/500
# 1/1 [==============================] - 0s 9ms/step - loss: 7.7811
# Epoch 8/500
# 1/1 [==============================] - 0s 9ms/step - loss: 6.3921
# Epoch 9/500
# 1/1 [==============================] - 0s 10ms/step - loss: 5.2938
# Epoch 10/500
# 1/1 [==============================] - 0s 9ms/step - loss: 4.4242
# Epoch 11/500
# 1/1 [==============================] - 0s 8ms/step - loss: 3.7348
# Epoch 12/500
# 1/1 [==============================] - 0s 8ms/step - loss: 3.1871
# ...

# %%
print(model.predict([10.0]))
print("Here is what I learned:", l0.get_weights())
# Out:
# 1/1 [==============================] - 0s 37ms/step
# [[18.979267]]
# Here is what I learned: [array([[1.996995]], dtype=float32), array([-0.9906834], dtype=float32)]
